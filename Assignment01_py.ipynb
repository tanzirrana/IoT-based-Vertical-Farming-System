# %% [markdown]
# <a href="https://colab.research.google.com/github/tanzirrana/IoT-based-Vertical-Farming-System/blob/main/Assignment01_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Basic Print

# %%
print("Welcome to Python Programming!")
print("I am learning the basics.")
# Out:
# Welcome to Python Programming!
# I am learning the basics.

# %% [markdown]
# #Print With Variables

# %%
name = "Tanzir Rana"
age = 25
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Tanzir Rana and I am 25 years old.

# %% [markdown]
# #User Input

# %%
name = input("Enter your name: ")
language = input("Enter your favourite programming language: ")

print(f"Hello {name}, your favourite language is {language}")
# Out:
# Enter your name: Tanzir Rana
# Enter your favourite programming language: Python
# Hello Tanzir Rana, your favourite language is Python

# %% [markdown]
# #Type casting (String to integer)

# %%
num1= input("Enter Number1: ")
num2= input("Enter Number2: ")
sum= int(num1)+int(num2)
print("The Sum is = ",sum)
# Out:
# Enter Number1: 10
# Enter Number2: 20
# The Sum is =  30

# %% [markdown]
# #Simple Calculator

# %%
num1= input("Enter num1: ")
num2= input("Enter num2: ")
Addition = int(num1) + int(num2)
Subtraction = int(num1)- int(num2)
Multiplicaton = int(num1)* int(num2)

print("Addition: ", Addition)
print("Subtraction: ", Subtraction)
print("Multiplicaton: ", Multiplicaton)
# Out:
# Enter num1: 20
# Enter num2: 10
# Addition:  30
# Subtraction:  10
# Multiplicaton:  200
